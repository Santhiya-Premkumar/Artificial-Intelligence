# %%
#Import Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load Dataset
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
# dataset preprocessing
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
# drop column - which column not required we can drop it
dataset= dataset.drop("User ID",axis=1)
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
#checking 0 and 1 counts in purchased column - also this is imbalanced Data 
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
#input and coutput columns
independent= dataset [['Age', 'EstimatedSalary','Gender_Male']]
dependent = dataset ['Purchased']

# %%
#input column size
independent.shape
# Out:
# (400, 3)

# %%
dependent.shape
# Out:
# (400,)

# %%
# train and test set split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=1/3,random_state=0)

#Standard Scaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train= sc.fit_transform(x_train)
x_test= sc.transform(x_test)

# %%
# Model Creation
from sklearn.linear_model import LogisticRegression

from sklearn.model_selection import GridSearchCV

param_grid = {'penalty':['l1','l2','elasticnet',None],'solver':['lbfgs','liblinear','saga'],'multi_class':['auto','ovr','multinomial']}

grid = GridSearchCV(LogisticRegression(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 

# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html#sklearn.metrics.f1_score

# fitting the model for grid search 
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 85 fits failed out of a total of 180.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 64, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1291, in fit
#     fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\joblib\parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\joblib\parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\joblib\parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\joblib\_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\joblib\parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\joblib\parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 521, in _logistic_regression_path
#     alpha = (1.0 / C) * (1 - l1_ratio)
#                          ~~^~~~~~~~~~
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1216, in fit
#     self.coef_, self.intercept_, self.n_iter_ = _fit_liblinear(
#                                                 ^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\svm\_base.py", line 1223, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\svm\_base.py", line 1062, in _get_liblinear_solver_type
#     raise ValueError(
# ValueError: Unsupported set of arguments: The combination of penalty='None' and loss='logistic_regression' is not supported, Parameters: penalty=None, loss='logistic_regression', dual=False
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 1207, in fit
#     multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py", line 90, in _check_multi_class
#     raise ValueError("Solver %s does not support a multinomial backend." % solver)
# ValueError: Solver liblinear does not support a multinomial backend.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\santhiya\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.82554202 0.82876593 0.82773722 0.82876593 0.82773722
#         nan        nan        nan 0.82876593        nan 0.82876593
#         nan 0.82554202 0.82876593 0.82773722 0.82876593 0.82773722
#         nan        nan        nan 0.82876593        nan 0.82876593
#         nan        nan 0.82876593 0.82876593        nan 0.82876593
#         nan        nan        nan 0.82876593        nan 0.82876593]
#   warnings.warn(
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'multi_class': ['auto', 'ovr', 'multinomial'],
#                          'penalty': ['l1', 'l2', 'elasticnet', None],
#                          'solver': ['lbfgs', 'liblinear', 'saga']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(x_test)

# %%
print(grid.best_params_)
table=pd.DataFrame.from_dict(re)
table
# Out:
# {'multi_class': 'auto', 'penalty': 'l1', 'solver': 'saga'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000277      0.000346         0.000000        0.000000
# 1        0.002517      0.004187         0.000562        0.000895
# 2        0.001079      0.001579         0.002735        0.001434
# 3        0.001502      0.001268         0.000000        0.000000
# 4        0.001677      0.002881         0.004680        0.003828
# 5        0.003203      0.003923         0.001601        0.003203
# 6        0.001601      0.003203         0.000000        0.000000
# 7        0.003200      0.003919         0.000000        0.000000
# 8        0.000253      0.000506         0.000000        0.000000
# 9        0.003854      0.004012         0.000000        0.000000
# 10       0.002655      0.003612         0.000000        0.000000
# 11       0.003793      0.004740         0.003200        0.003919
# 12       0.000000      0.000000         0.000000        0.000000
# 13       0.001600      0.003201         0.003425        0.004210
# 14       0.000325      0.000651         0.001925        0.003850
# 15       0.003526      0.004349         0.003201        0.003921
# 16       0.003201      0.003920         0.000325        0.000651
# 17       0.003202      0.003922         0.001600        0.003200
# 18       0.003201      0.003921         0.000000        0.000000
# 19       0.000000      0.000000         0.000000        0.000000
# 20       0.000000      0.000000         0.000000        0.000000
# 21       0.004812      0.003929         0.001600        0.003200
# 22       0.001606      0.003212         0.000000        0.000000
# 23       0.000000      0.000000         0.000000        0.000000
# 24       0.000000      0.000000         0.000000        0.000000
# 25       0.000000      0.000000         0.000000        0.000000
# 26       0.003125      0.006249         0.000602        0.001204
# 27       0.004731      0.006272         0.000000        0.000000
# 28       0.003126      0.006251         0.000000        0.000000
# 29       0.003125      0.006249         0.000602        0.001204
# 30       0.000000      0.000000         0.000000        0.000000
# 31       0.000000      0.000000         0.000000        0.000000
# 32       0.003126      0.006251         0.000000        0.000000
# 33       0.000000      0.000000         0.006251        0.007656
# 34       0.003126      0.006251         0.000000        0.000000
# 35       0.003125      0.006249         0.000000        0.000000
#
#    param_multi_class param_penalty param_solver  \
# 0               auto            l1        lbfgs
# 1               auto            l1    liblinear
# 2               auto            l1         saga
# 3               auto            l2        lbfgs
# 4               auto            l2    liblinear
# 5               auto            l2         saga
# 6               auto    elasticnet        lbfgs
# 7               auto    elasticnet    liblinear
# 8               auto    elasticnet         saga
# 9               auto          None        lbfgs
# 10              auto          None    liblinear
# 11              auto          None         saga
# 12               ovr            l1        lbfgs
# 13               ovr            l1    liblinear
# 14               ovr            l1         saga
# 15               ovr            l2        lbfgs
# 16               ovr            l2    liblinear
# 17               ovr            l2         saga
# 18               ovr    elasticnet        lbfgs
# 19               ovr    elasticnet    liblinear
# 20               ovr    elasticnet         saga
# 21               ovr          None        lbfgs
# 22               ovr          None    liblinear
# 23               ovr          None         saga
# 24       multinomial            l1        lbfgs
# 25       multinomial            l1    liblinear
# 26       multinomial            l1         saga
# 27       multinomial            l2        lbfgs
# 28       multinomial            l2    liblinear
# 29       multinomial            l2         saga
# 30       multinomial    elasticnet        lbfgs
# 31       multinomial    elasticnet    liblinear
# 32       multinomial    elasticnet         saga
# 33       multinomial          None        lbfgs
# 34       multinomial          None    liblinear
# 35       multinomial          None         saga
#
#                                                params  split0_test_score  \
# 0   {'multi_class': 'auto', 'penalty': 'l1', 'solv...                NaN
# 1   {'multi_class': 'auto', 'penalty': 'l1', 'solv...           0.804764
# 2   {'multi_class': 'auto', 'penalty': 'l1', 'solv...           0.804764
# 3   {'multi_class': 'auto', 'penalty': 'l2', 'solv...           0.799620
# 4   {'multi_class': 'auto', 'penalty': 'l2', 'solv...           0.804764
# 5   {'multi_class': 'auto', 'penalty': 'l2', 'solv...           0.799620
# 6   {'multi_class': 'auto', 'penalty': 'elasticnet...                NaN
# 7   {'multi_class': 'auto', 'penalty': 'elasticnet...                NaN
# 8   {'multi_class': 'auto', 'penalty': 'elasticnet...                NaN
# 9   {'multi_class': 'auto', 'penalty': None, 'solv...           0.804764
# 10  {'multi_class': 'auto', 'penalty': None, 'solv...                NaN
# 11  {'multi_class': 'auto', 'penalty': None, 'solv...           0.804764
# 12  {'multi_class': 'ovr', 'penalty': 'l1', 'solve...                NaN
# 13  {'multi_class': 'ovr', 'penalty': 'l1', 'solve...           0.804764
# 14  {'multi_class': 'ovr', 'penalty': 'l1', 'solve...           0.804764
# 15  {'multi_class': 'ovr', 'penalty': 'l2', 'solve...           0.799620
# 16  {'multi_class': 'ovr', 'penalty': 'l2', 'solve...           0.804764
# 17  {'multi_class': 'ovr', 'penalty': 'l2', 'solve...           0.799620
# 18  {'multi_class': 'ovr', 'penalty': 'elasticnet'...                NaN
# 19  {'multi_class': 'ovr', 'penalty': 'elasticnet'...                NaN
# 20  {'multi_class': 'ovr', 'penalty': 'elasticnet'...                NaN
# 21  {'multi_class': 'ovr', 'penalty': None, 'solve...           0.804764
# 22  {'multi_class': 'ovr', 'penalty': None, 'solve...                NaN
# 23  {'multi_class': 'ovr', 'penalty': None, 'solve...           0.804764
# 24  {'multi_class': 'multinomial', 'penalty': 'l1'...                NaN
# 25  {'multi_class': 'multinomial', 'penalty': 'l1'...                NaN
# 26  {'multi_class': 'multinomial', 'penalty': 'l1'...           0.804764
# 27  {'multi_class': 'multinomial', 'penalty': 'l2'...           0.804764
# 28  {'multi_class': 'multinomial', 'penalty': 'l2'...                NaN
# 29  {'multi_class': 'multinomial', 'penalty': 'l2'...           0.804764
# 30  {'multi_class': 'multinomial', 'penalty': 'ela...                NaN
# 31  {'multi_class': 'multinomial', 'penalty': 'ela...                NaN
# 32  {'multi_class': 'multinomial', 'penalty': 'ela...                NaN
# 33  {'multi_class': 'multinomial', 'penalty': None...           0.804764
# 34  {'multi_class': 'multinomial', 'penalty': None...                NaN
# 35  {'multi_class': 'multinomial', 'penalty': None...           0.804764
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1            0.811321            0.66593            0.92351
# 2            0.811321            0.68205            0.92351
# 3            0.811321            0.68205            0.92351
# 4            0.811321            0.68205            0.92351
# 5            0.811321            0.68205            0.92351
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8                 NaN                NaN                NaN
# 9            0.811321            0.68205            0.92351
# 10                NaN                NaN                NaN
# 11           0.811321            0.68205            0.92351
# 12                NaN                NaN                NaN
# 13           0.811321            0.66593            0.92351
# 14           0.811321            0.68205            0.92351
# 15           0.811321            0.68205            0.92351
# 16           0.811321            0.68205            0.92351
# 17           0.811321            0.68205            0.92351
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20                NaN                NaN                NaN
# 21           0.811321            0.68205            0.92351
# 22                NaN                NaN                NaN
# 23           0.811321            0.68205            0.92351
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26           0.811321            0.68205            0.92351
# 27           0.811321            0.68205            0.92351
# 28                NaN                NaN                NaN
# 29           0.811321            0.68205            0.92351
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
# 32                NaN                NaN                NaN
# 33           0.811321            0.68205            0.92351
# 34                NaN                NaN                NaN
# 35           0.811321            0.68205            0.92351
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               20
# 1            0.922185         0.825542        0.094918               18
# 2            0.922185         0.828766        0.089565                1
# 3            0.922185         0.827737        0.089864               14
# 4            0.922185         0.828766        0.089565                1
# 5            0.922185         0.827737        0.089864               14
# 6                 NaN              NaN             NaN               20
# 7                 NaN              NaN             NaN               20
# 8                 NaN              NaN             NaN               20
# 9            0.922185         0.828766        0.089565                1
# 10                NaN              NaN             NaN               20
# 11           0.922185         0.828766        0.089565                1
# 12                NaN              NaN             NaN               20
# 13           0.922185         0.825542        0.094918               18
# 14           0.922185         0.828766        0.089565                1
# 15           0.922185         0.827737        0.089864               14
# 16           0.922185         0.828766        0.089565                1
# 17           0.922185         0.827737        0.089864               14
# 18                NaN              NaN             NaN               20
# 19                NaN              NaN             NaN               20
# 20                NaN              NaN             NaN               20
# 21           0.922185         0.828766        0.089565                1
# 22                NaN              NaN             NaN               20
# 23           0.922185         0.828766        0.089565                1
# 24                NaN              NaN             NaN               20
# 25                NaN              NaN             NaN               20
# 26           0.922185         0.828766        0.089565                1
# 27           0.922185         0.828766        0.089565                1
# 28                NaN              NaN             NaN               20
# 29           0.922185         0.828766        0.089565                1
# 30                NaN              NaN             NaN               20
# 31                NaN              NaN             NaN               20
# 32                NaN              NaN             NaN               20
# 33           0.922185         0.828766        0.089565                1
# 34                NaN              NaN             NaN               20
# 35           0.922185         0.828766        0.089565                1

# %%
# here going to use confusion matrix instead of R2_Score
from sklearn.metrics import confusion_matrix
cm = confusion_matrix (y_test,grid_predictions)
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[79  6]
#  [10 39]]

# %%
# Classification report to find recall, f1_score, precision, support
from sklearn.metrics import classification_report
clf_report =classification_report(y_test,grid_predictions)
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        85
#            1       0.87      0.80      0.83        49
#
#     accuracy                           0.88       134
#    macro avg       0.88      0.86      0.87       134
# weighted avg       0.88      0.88      0.88       134

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'multi_class': 'auto', 'penalty': 'l1', 'solver': 'saga'}: 0.8794289739855382

# %%
#age_input=float(input("Age:"))
#salary_input=float(input("BMI:"))
#sex_male_input=int(input("Sex Male 0 or 1:"))
#classifier.predict([[age_input,salary_input,sex_male_input]])
