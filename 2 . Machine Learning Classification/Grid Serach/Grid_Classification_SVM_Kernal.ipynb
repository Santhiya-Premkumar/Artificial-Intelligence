# %%
#Import Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Load Dataset
dataset=pd.read_csv("Social_Network_Ads.csv")
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
# dataset preprocessing
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       User ID  Age  EstimatedSalary  Purchased  Gender_Male
# 0    15624510   19            19000          0            1
# 1    15810944   35            20000          0            1
# 2    15668575   26            43000          0            0
# 3    15603246   27            57000          0            0
# 4    15804002   19            76000          0            1
# ..        ...  ...              ...        ...          ...
# 395  15691863   46            41000          1            0
# 396  15706071   51            23000          1            1
# 397  15654296   50            20000          1            0
# 398  15755018   36            33000          0            1
# 399  15594041   49            36000          1            0
#
# [400 rows x 5 columns]

# %%
# drop column - which column not required we can drop it
dataset= dataset.drop("User ID",axis=1)
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
#checking 0 and 1 counts in purchased column - also this is imbalanced Data 
dataset["Purchased"].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
dataset.columns
# Out:
# Index(['Age', 'EstimatedSalary', 'Purchased', 'Gender_Male'], dtype='object')

# %%
#input and coutput columns
independent= dataset [['Age', 'EstimatedSalary','Gender_Male']]
dependent = dataset ['Purchased']

# %%
#input column size
independent.shape
# Out:
# (400, 3)

# %%
dependent.shape
# Out:
# (400,)

# %%
# train and test set split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(independent,dependent,test_size=1/3,random_state=0)

#Standard Scaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train= sc.fit_transform(x_train)
x_test= sc.transform(x_test)

# %%
# Model Creation
from sklearn.svm import SVC

from sklearn.model_selection import GridSearchCV

param_grid = {'C':[10,100],'kernel':['poly','rbf','sigmoid'],'gamma':['scale','auto']}

grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 

# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html#sklearn.metrics.f1_score

# fitting the model for grid search 
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=SVC(), n_jobs=-1,
#              param_grid={'C': [10, 100], 'gamma': ['scale', 'auto'],
#                          'kernel': ['poly', 'rbf', 'sigmoid']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(x_test)

# %%
 # Data Table Format
print(grid.best_params_)
table=pd.DataFrame.from_dict(re)
table
# Out:
# {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_C  \
# 0        0.002821      0.003006         0.004222        0.003256      10
# 1        0.002820      0.003727         0.003214        0.003936      10
# 2        0.006850      0.003517         0.002834        0.002737      10
# 3        0.003219      0.003942         0.006042        0.003359      10
# 4        0.005630      0.004655         0.002016        0.003119      10
# 5        0.003601      0.003546         0.002620        0.002494      10
# 6        0.019038      0.011188         0.002244        0.002647     100
# 7        0.007615      0.002357         0.001565        0.001454     100
# 8        0.004436      0.002963         0.001907        0.001008     100
# 9        0.013466      0.002618         0.001195        0.001503     100
# 10       0.003856      0.002507         0.002388        0.002152     100
# 11       0.002534      0.000737         0.002500        0.000590     100
#
#    param_gamma param_kernel  \
# 0        scale         poly
# 1        scale          rbf
# 2        scale      sigmoid
# 3         auto         poly
# 4         auto          rbf
# 5         auto      sigmoid
# 6        scale         poly
# 7        scale          rbf
# 8        scale      sigmoid
# 9         auto         poly
# 10        auto          rbf
# 11        auto      sigmoid
#
#                                                params  split0_test_score  \
# 0       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.799620
# 1        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 2    {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.762677
# 3        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.799620
# 4         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 5     {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.762677
# 6      {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.822092
# 7       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.867478
# 8   {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoid'}           0.808927
# 9       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.822092
# 10       {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.867478
# 11   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid'}           0.808927
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.808392           0.787943           0.924528
# 1            0.886792           0.869709           0.944161
# 2            0.738916           0.753180           0.778067
# 3            0.808392           0.787943           0.924528
# 4            0.886792           0.869709           0.944161
# 5            0.738916           0.655795           0.796284
# 6            0.787284           0.766556           0.924528
# 7            0.886792           0.870362           0.944161
# 8            0.714931           0.698113           0.796284
# 9            0.787284           0.766556           0.924528
# 10           0.886792           0.870362           0.944161
# 11           0.714931           0.633719           0.718497
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.901744         0.844445        0.056918                5
# 1            0.943041         0.902236        0.034431                3
# 2            0.766556         0.759879        0.013172                9
# 3            0.901744         0.844445        0.056918                5
# 4            0.943041         0.902236        0.034431                3
# 5            0.766556         0.744045        0.047743               11
# 6            0.901744         0.840441        0.062370                7
# 7            0.943041         0.902367        0.034308                1
# 8            0.766556         0.756962        0.043745               10
# 9            0.901744         0.840441        0.062370                7
# 10           0.943041         0.902367        0.034308                1
# 11           0.766556         0.728526        0.058625               12

# %%
# here going to use confusion matrix instead of R2_Score
from sklearn.metrics import confusion_matrix
cm = confusion_matrix (y_test,grid_predictions)
print("The confusion Matrix:\n",cm)
# Out:
# The confusion Matrix:
#  [[80  5]
#  [ 7 42]]

# %%
# Classification report to find recall, f1_score, precision, support
from sklearn.metrics import classification_report
clf_report =classification_report(y_test,grid_predictions)
print("The report:\n",clf_report)
# Out:
# The report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.94      0.93        85
#            1       0.89      0.86      0.88        49
#
#     accuracy                           0.91       134
#    macro avg       0.91      0.90      0.90       134
# weighted avg       0.91      0.91      0.91       134

# %%
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}: 0.9100355779243318

# %%
#age_input=float(input("Age:"))
#salary_input=float(input("BMI:"))
#sex_male_input=int(input("Sex Male 0 or 1:"))
#classifier.predict([[age_input,salary_input,sex_male_input]])
